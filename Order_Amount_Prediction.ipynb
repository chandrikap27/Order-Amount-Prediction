# %% [markdown]
# <a href="https://colab.research.google.com/github/chandrikap27/Order-Amount-Prediction/blob/main/Order_Amount_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### NAME : Chandrika Papneja

# %% [markdown]
# ## MILESTONE-1 : Data Sanity ( by using Numpy and Pandas)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Use the PRS dataset to create a dataframe

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv("/content/drive/MyDrive/Final.csv")

# %% [markdown]
# Check the description of the dataframe

# %%
df.describe()
# Out:
#        CUSTOMER_ORDER_ID     SALES_ORG  COMPANY_CODE  ORDER_CREATION_DATE  \
# count       1.101925e+06  1.101925e+06  1.101925e+06         1.101925e+06
# mean        8.763187e+08  3.304891e+03  3.431364e+03         2.022032e+07
# std         7.088594e+07  6.958920e+02  5.483805e+02         1.426756e+02
# min         7.534520e+08  2.100000e+03  5.900000e+01         2.022010e+07
# 25%         8.149522e+08  2.702000e+03  3.260000e+03         2.022021e+07
# 50%         8.763963e+08  3.305000e+03  3.660000e+03         2.022032e+07
# 75%         9.376832e+08  3.908000e+03  3.670000e+03         2.022042e+07
# max         9.990063e+08  4.510000e+03  4.260000e+03         2.022060e+07
#
#        ORDER_CREATION_TIME  SOLD_TO_PARTY  REQUESTED_DELIVERY_DATE  \
# count         1.101925e+06   1.101925e+06             1.101925e+06
# mean          1.340316e+05   8.763265e+08             2.022035e+07
# std           6.503618e+04   7.090306e+07             1.751912e+03
# ...

# %% [markdown]
# Check the shape of the dataframe

# %%
df.shape #Retrieve the shape of the DataFrame 'df'
# Out:
# (1101925, 16)

# %% [markdown]
# Check the data frame informations

# %%
df.info() # Display information about the DataFrame 'df'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1101925 entries, 0 to 1101924
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   CUSTOMER_ORDER_ID        1101925 non-null  int64
#  1   SALES_ORG                1101925 non-null  int64
#  2   DISTRIBUTION_CHANNEL     1101925 non-null  object
#  3   DIVISION                 1101925 non-null  object
#  4   RELEASED_CREDIT_VALUE    1101925 non-null  object
#  5   PURCHASE_ORDER_TYPE      1083233 non-null  object
#  6   COMPANY_CODE             1101925 non-null  int64
#  7   ORDER_CREATION_DATE      1101925 non-null  int64
#  8   ORDER_CREATION_TIME      1101925 non-null  int64
#  9   CREDIT_CONTROL_AREA      1101925 non-null  object
#  10  SOLD_TO_PARTY            1101925 non-null  int64
#  11  ORDER_AMOUNT             1101925 non-null  object
#  12  REQUESTED_DELIVERY_DATE  1101925 non-null  int64
# ...

# %% [markdown]
# Check for the Null values in the dataframe

# %%
df.isnull().sum()
# Out:
# CUSTOMER_ORDER_ID               0
# SALES_ORG                       0
# DISTRIBUTION_CHANNEL            0
# DIVISION                        0
# RELEASED_CREDIT_VALUE           0
# PURCHASE_ORDER_TYPE         18692
# COMPANY_CODE                    0
# ORDER_CREATION_DATE             0
# ORDER_CREATION_TIME             0
# CREDIT_CONTROL_AREA             0
# SOLD_TO_PARTY                   0
# ORDER_AMOUNT                    0
# REQUESTED_DELIVERY_DATE         0
# ORDER_CURRENCY                  0
# CREDIT_STATUS              882447
# CUSTOMER_NUMBER                 0
# dtype: int64

# %% [markdown]
# Replace all the null values with "NaN"

# %%
df.fillna("NAN",inplace=True)

# %%
df.tail()#prints the last 5 rows of the dataframe df
# Out:
#          CUSTOMER_ORDER_ID  SALES_ORG DISTRIBUTION_CHANNEL      DIVISION  \
# 1101920          853605710       2498              Germany  South-Region
# 1101921          998890898       4509              Armenia  South-Region
# 1101922          983330221       3951                Nepal  South-Region
# 1101923          926668029       3235               Panama  South-Region
# 1101924          921701000       2968            Nicaragua  South-Region
#
#         RELEASED_CREDIT_VALUE PURCHASE_ORDER_TYPE  COMPANY_CODE  \
# 1101920                  0,00                 NAN          4260
# 1101921                  0,00                 NAN          4260
# 1101922                  0,00                 NAN          4260
# 1101923                  0,00                 NAN          4260
# 1101924                  0,00                 NAN          4260
#
#          ORDER_CREATION_DATE  ORDER_CREATION_TIME CREDIT_CONTROL_AREA  \
# ...

# %% [markdown]
# Change the format of date columns - "ORDER_CREATION_DATE" to datetime[64] with the format as "%Y%m%d"

# %%
df["ORDER_CREATION_DATE"] = pd.to_datetime(df["ORDER_CREATION_DATE"], format="%Y%m%d")

# %%
df.head()
# Out:
#    CUSTOMER_ORDER_ID  SALES_ORG      DISTRIBUTION_CHANNEL      DIVISION  \
# 0          946851639       3537  United States of America  South-Region
# 1          963432061       3449                Martinique  South-Region
# 2          971991639       3238                   Moldova  South-Region
# 3          754349803       3911      United Arab Emirates  South-Region
# 4          930253442       2381                    Greece  South-Region
#
#   RELEASED_CREDIT_VALUE PURCHASE_ORDER_TYPE  COMPANY_CODE ORDER_CREATION_DATE  \
# 0                  0,00                1000          3220          2022-01-01
# 1                  0,00                1000          3220          2022-01-01
# 2              82342,02                I200          3260          2022-01-01
# 3               1471,24                N000          3290          2022-01-01
# 4                  0,00                N000          3290          2022-01-01
#
# ...

# %% [markdown]
#  "REQUESTED_DELIVERY_DATE" to datetime[64] with the format as "%Y%m%d"

# %%
df["REQUESTED_DELIVERY_DATE"] = pd.to_datetime(df["REQUESTED_DELIVERY_DATE"], format="%Y%m%d")

# %%
df.head()
# Out:
#    CUSTOMER_ORDER_ID  SALES_ORG      DISTRIBUTION_CHANNEL      DIVISION  \
# 0          946851639       3537  United States of America  South-Region
# 1          963432061       3449                Martinique  South-Region
# 2          971991639       3238                   Moldova  South-Region
# 3          754349803       3911      United Arab Emirates  South-Region
# 4          930253442       2381                    Greece  South-Region
#
#   RELEASED_CREDIT_VALUE PURCHASE_ORDER_TYPE  COMPANY_CODE ORDER_CREATION_DATE  \
# 0                  0,00                1000          3220          2022-01-01
# 1                  0,00                1000          3220          2022-01-01
# 2              82342,02                I200          3260          2022-01-01
# 3               1471,24                N000          3290          2022-01-01
# 4                  0,00                N000          3290          2022-01-01
#
# ...

# %% [markdown]
# Sanity check - Check how many records are having order date greater than the delivery date

# %%
num_records = len(df[df["ORDER_CREATION_DATE"] > df["REQUESTED_DELIVERY_DATE"]]) #Count the number of rows where ORDER_CREATION_DATE is greater than REQUESTED_DELIVERY_DATE

# %%
num_records
# Out:
# 27142

# %% [markdown]
# Remove those records where order date is greater than the delivery date

# %%
df = df[df["ORDER_CREATION_DATE"] <= df["REQUESTED_DELIVERY_DATE"]] #store only those rows in the dataframe where ORDER_CREATION_DATE is less than REQUESTED_DELIVERY_DATE

# %%
num_records = len(df[df["ORDER_CREATION_DATE"] > df["REQUESTED_DELIVERY_DATE"]])

# %%
num_records #recheck by printing the count of the number of rows where ORDER_CREATION_DATE is greater than REQUESTED_DELIVERY_DATE which should be 0
# Out:
# 0

# %%
df.head()
# Out:
#    CUSTOMER_ORDER_ID  SALES_ORG      DISTRIBUTION_CHANNEL      DIVISION  \
# 0          946851639       3537  United States of America  South-Region
# 1          963432061       3449                Martinique  South-Region
# 2          971991639       3238                   Moldova  South-Region
# 3          754349803       3911      United Arab Emirates  South-Region
# 4          930253442       2381                    Greece  South-Region
#
#   RELEASED_CREDIT_VALUE PURCHASE_ORDER_TYPE  COMPANY_CODE ORDER_CREATION_DATE  \
# 0                  0,00                1000          3220          2022-01-01
# 1                  0,00                1000          3220          2022-01-01
# 2              82342,02                I200          3260          2022-01-01
# 3               1471,24                N000          3290          2022-01-01
# 4                  0,00                N000          3290          2022-01-01
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1074783 entries, 0 to 1101924
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   CUSTOMER_ORDER_ID        1074783 non-null  int64
#  1   SALES_ORG                1074783 non-null  int64
#  2   DISTRIBUTION_CHANNEL     1074783 non-null  object
#  3   DIVISION                 1074783 non-null  object
#  4   RELEASED_CREDIT_VALUE    1074783 non-null  object
#  5   PURCHASE_ORDER_TYPE      1074783 non-null  object
#  6   COMPANY_CODE             1074783 non-null  int64
#  7   ORDER_CREATION_DATE      1074783 non-null  datetime64[ns]
#  8   ORDER_CREATION_TIME      1074783 non-null  int64
#  9   CREDIT_CONTROL_AREA      1074783 non-null  object
#  10  SOLD_TO_PARTY            1074783 non-null  int64
#  11  ORDER_AMOUNT             1074783 non-null  object
#  12  REQUESTED_DELIVERY_DATE  1074783 non-null  datetime64[ns]
# ...

# %% [markdown]
# Check the number of records where the “ORDER_AMOUNT” field is having “-” in it.

# %%
num_with_dash = len(df[df["ORDER_AMOUNT"].str.contains("-")])

# %%
num_with_dash
# Out:
# 32

# %% [markdown]
# Replace “-” with “” from the “ORDER_AMOUNT” field.

# %%
df["ORDER_AMOUNT"] = df["ORDER_AMOUNT"].str.replace("-", "")

# %%
num_with_dash = len(df[df["ORDER_AMOUNT"].str.contains("-")])
num_with_dash
# Out:
# 0

# %% [markdown]
# Check the number of records where the “ORDER_AMOUNT” field is having “,” in it.

# %%
num_with_comma = len(df[df["ORDER_AMOUNT"].str.contains(",")])
num_with_comma
# Out:
# 1073406

# %% [markdown]
# Replace “,” with “.” from the “ORDER_AMOUNT” field.

# %%
df["ORDER_AMOUNT"] = df["ORDER_AMOUNT"].str.replace(",", ".")

# %%
num_with_comma = len(df[df["ORDER_AMOUNT"].str.contains(",")])
num_with_comma
# Out:
# 0

# %% [markdown]
# Count the number of records where the order date and the delivery date are same

# %%
len(df[df["ORDER_CREATION_DATE"] == df["REQUESTED_DELIVERY_DATE"]])
# Out:
# 100437

# %%
df.head()
# Out:
#    CUSTOMER_ORDER_ID  SALES_ORG      DISTRIBUTION_CHANNEL      DIVISION  \
# 0          946851639       3537  United States of America  South-Region
# 1          963432061       3449                Martinique  South-Region
# 2          971991639       3238                   Moldova  South-Region
# 3          754349803       3911      United Arab Emirates  South-Region
# 4          930253442       2381                    Greece  South-Region
#
#   RELEASED_CREDIT_VALUE PURCHASE_ORDER_TYPE  COMPANY_CODE ORDER_CREATION_DATE  \
# 0                  0,00                1000          3220          2022-01-01
# 1                  0,00                1000          3220          2022-01-01
# 2              82342,02                I200          3260          2022-01-01
# 3               1471,24                N000          3290          2022-01-01
# 4                  0,00                N000          3290          2022-01-01
#
# ...

# %% [markdown]
# Count the number of records for each currency type by using the field “'ORDER_CURRENCY'”

# %%
df["ORDER_CURRENCY"].value_counts()
# Out:
# USD    622835
# EUR    253196
# AUD     64200
# CAD     55065
# GBP     22028
# MYR     13946
# PLN     11861
# AED      7852
# HKD      6198
# CHF      5259
# RON      4731
# SGD      3909
# CZK      2178
# HU1      1377
# NZD        79
# BHD        32
# SAR        14
# QAR        12
# KWD         7
# SEK         4
# Name: ORDER_CURRENCY, dtype: int64

# %% [markdown]
# Create a new column in the existing dataframe as “'amount_in_usd'” and convert all the non-USD currencies in USD and store them in the same column.

# %%
conversion_rates = {
    "EUR": 0.93,
    "AUD": 1.53,
    "CAD": 1.36,
    "GBP": 0.81,
    "MYR": 4.59,
    "PLN": 4.19,
    "AED": 3.67,
    "HKD": 7.83,
    "CHF": 0.91,
    "RON": 4.61,
    "SGD": 1.35,
    "CZK": 22.01,
    "HUF": 346.58,
    "NZD": 1.64,
    "BHD": 0.38,
    "SAR": 3.75,
    "QAR": 3.64,
    "KWD": 0.31,
    "SEK": 10.72
}

df["ORDER_AMOUNT"] = pd.to_numeric(df["ORDER_AMOUNT"], errors="coerce")
df["amount_in_usd"] = df.apply(lambda row: row["ORDER_AMOUNT"] / conversion_rates.get(row["ORDER_CURRENCY"], 1), axis=1)
print(df['amount_in_usd'])
# Out:
# 0           1026.462366
# 1            846.623656
# 2          72573.612903
# 3           1511.333333
# 4              0.000000
#                ...
# 1101920     3270.511111
# 1101921        0.000000
# 1101922        0.000000
# 1101923        0.000000
# 1101924     3270.511111
# Name: amount_in_usd, Length: 1074783, dtype: float64

# %% [markdown]
# Check for values “0” in the “'amount_in_usd” column.

# %%
zero_values = df[df['amount_in_usd'] == 0]
print(zero_values)
# Out:
#          CUSTOMER_ORDER_ID  SALES_ORG DISTRIBUTION_CHANNEL      DIVISION  \
# 4                930253442       2381               Greece  South-Region
# 57               778638920       2373             Thailand  South-Region
# 62               870847173       4352               Poland  North-Region
# 67               822817658       2491          Netherlands  North-Region
# 117              799548044       2849              Belgium  South-Region
# ...                    ...        ...                  ...           ...
# 1101891          835314074       3410               Taiwan  South-Region
# 1101892          958175613       4452           Mauritania  South-Region
# 1101921          998890898       4509              Armenia  South-Region
# 1101922          983330221       3951                Nepal  South-Region
# 1101923          926668029       3235               Panama  South-Region
#
#         RELEASED_CREDIT_VALUE PURCHASE_ORDER_TYPE  COMPANY_CODE  \
# ...

# %% [markdown]
# Create a new column in the existing dataframe “unique_cust_id” by adding 'CUSTOMER_NUMBER' and 'COMPANY_CODE'

# %%
df['unique_cust_id'] = df.apply(lambda x : str(x["CUSTOMER_NUMBER"]) + str(x["COMPANY_CODE"]), axis=1)

# %%
df.head()
# Out:
#    CUSTOMER_ORDER_ID  SALES_ORG      DISTRIBUTION_CHANNEL      DIVISION  \
# 0          946851639       3537  United States of America  South-Region
# 1          963432061       3449                Martinique  South-Region
# 2          971991639       3238                   Moldova  South-Region
# 3          754349803       3911      United Arab Emirates  South-Region
# 4          930253442       2381                    Greece  South-Region
#
#   RELEASED_CREDIT_VALUE PURCHASE_ORDER_TYPE  COMPANY_CODE ORDER_CREATION_DATE  \
# 0                  0,00                1000          3220          2022-01-01
# 1                  0,00                1000          3220          2022-01-01
# 2              82342,02                I200          3260          2022-01-01
# 3               1471,24                N000          3290          2022-01-01
# 4                  0,00                N000          3290          2022-01-01
#
# ...

# %%
df.shape
# Out:
# (1074783, 18)

# %% [markdown]
# ## MILESTONE-2 : EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Create a Histogram on DISTRIBUTION_CHANNEL

# %%
plt.figure(figsize=(20, 6))
plt.hist(df['DISTRIBUTION_CHANNEL'], bins='auto', edgecolor="black")
plt.xlabel('Distribution Channel')
plt.xticks(fontsize=5)
plt.ylabel('Frequency')
plt.title('Distribution of Data by Channel')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Create a Pie Chart on ORDER_CURRENCY

# %%
plt.pie(df["ORDER_CURRENCY"].value_counts(),autopct='%1.1f%%',textprops={'fontsize': 5})
plt.legend(df['ORDER_CURRENCY'].unique(), loc='upper left')
plt.show()

# %% [markdown]
# Create a line chart PURCHASE_ORDER_TYPE and DISTRIBUTION_CHANNEL

# %%
sns.lineplot(x=df['PURCHASE_ORDER_TYPE'], y=df['DISTRIBUTION_CHANNEL'], data=df)
plt.yticks([])
plt.xticks(fontsize=3, rotation=90)
plt.show()

# %% [markdown]
# Create a line plot on ORDER_CREATION_DATE and amount_in_usd

# %%
sns.lineplot(x=df['ORDER_CREATION_DATE'], y=df['amount_in_usd'], data=df)
plt.show()

# %% [markdown]
# Create a boxplot on ORDER_AMOUNT	to find out the outliers

# %%
plt.boxplot(df["ORDER_AMOUNT"])
plt.xlabel("ORDER_AMOUNT")
plt.title("Boxplot of ORDER_AMOUNT")
plt.show()

# %% [markdown]
# Create a barchart on COMPANY_CODE	 and ORDER_AMOUNT

# %%
df = df.sort_values(by=['ORDER_AMOUNT'], ascending=False)
sns.barplot(x=df['COMPANY_CODE'], y=df['ORDER_AMOUNT'], data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## MILESTONE-3 : Feature Engineering and Selection

# %%
import sklearn

from sklearn.feature_selection import SelectKBest
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import ColumnTransformer

# %% [markdown]
# Check for the outliers in the “amount_in_usd” column and replace the outliers with appropriate values, discussed in the sessions.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['amount_in_usd'])
# Out:
# <Axes: xlabel='amount_in_usd'>

# %%
df['amount_in_usd'].skew()
# Out:
# 262.46825614983726

# %%
Q1 = df['amount_in_usd'].quantile(0.25)
Q3 = df['amount_in_usd'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)

# %%
print(lower_bound)
print(upper_bound)
# Out:
# -1065.9290322580646
# 1812.6774193548388

# %%
df[df['amount_in_usd'] < lower_bound]
# Out:
# Empty DataFrame
# Columns: [CUSTOMER_ORDER_ID, SALES_ORG, DISTRIBUTION_CHANNEL, DIVISION, RELEASED_CREDIT_VALUE, PURCHASE_ORDER_TYPE, COMPANY_CODE, ORDER_CREATION_DATE, ORDER_CREATION_TIME, CREDIT_CONTROL_AREA, SOLD_TO_PARTY, ORDER_AMOUNT, REQUESTED_DELIVERY_DATE, ORDER_CURRENCY, CREDIT_STATUS, CUSTOMER_NUMBER, amount_in_usd, unique_cust_id]
# Index: []

# %%
df[df['amount_in_usd'] > upper_bound]
# Out:
#         CUSTOMER_ORDER_ID  SALES_ORG               DISTRIBUTION_CHANNEL  \
# 119897          980541538       4319                              Benin
# 141602          863699828       2481                              Sudan
# 4920            979579904       2589           Northern Mariana Islands
# 213416          956803025       2472                              Macao
# 258676          922197823       2917                             Greece
# ...                   ...        ...                                ...
# 272349          778681177       3478        French Southern Territories
# 6594            850727081       3034                               Iraq
# 10700           938916789       2593  Heard Island and McDonald Islands
# 65073           916846762       2726                             Taiwan
# 76827           795182182       2509                            Georgia
#
#             DIVISION RELEASED_CREDIT_VALUE PURCHASE_ORDER_TYPE  COMPANY_CODE  \
# ...

# %%
outliers = df[(df['amount_in_usd'] < lower_bound) | (df['amount_in_usd'] > upper_bound)]
pre_outliers = len(outliers)
print("Number of outliers remaining:", pre_outliers)
# Out:
# Number of outliers remaining: 101733

# %%
df.loc[df['amount_in_usd'] > upper_bound, 'amount_in_usd'] = upper_bound
df.loc[df['amount_in_usd'] < lower_bound, 'amount_in_usd'] = lower_bound

# %%
remaining_outliers = df[(df['amount_in_usd'] < lower_bound) | (df['amount_in_usd'] > upper_bound)]
post_outliers = len(remaining_outliers)
print("Number of outliers remaining:",post_outliers)
# Out:
# Number of outliers remaining: 0

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['amount_in_usd'])
# Out:
# <Axes: xlabel='amount_in_usd'>

# %%
# median = df['amount_in_usd'].median()
# df['amount_in_usd'] = df['amount_in_usd'].mask(df['amount_in_usd'] > 2000000,median)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder() #used for encoding categorical features into numeric values

categorical_columns = []

categorical_columns = df.select_dtypes(['object', 'category']).columns #store the names of columns that are of object or category data type
for column in categorical_columns:
    df[column] = df[column].astype(str)
    df[column] = le.fit_transform(df[column])
print(categorical_columns)
df.head()
# Out:
# Index(['DISTRIBUTION_CHANNEL', 'DIVISION', 'RELEASED_CREDIT_VALUE',
#        'PURCHASE_ORDER_TYPE', 'CREDIT_CONTROL_AREA', 'ORDER_CURRENCY',
#        'CREDIT_STATUS', 'unique_cust_id'],
#       dtype='object')
#         CUSTOMER_ORDER_ID  SALES_ORG  DISTRIBUTION_CHANNEL  DIVISION  \
# 119897          980541538       4319                    22         0
# 141602          863699828       2481                   205         0
# 4920            979579904       2589                   161         0
# 213416          956803025       2472                   126         0
# 258676          922197823       2917                    82         0
#
#         RELEASED_CREDIT_VALUE  PURCHASE_ORDER_TYPE  COMPANY_CODE  \
# 119897                   9938                  104           136
# 141602                   5925                  104           136
# 4920                    45824                  104           136
# 213416                  44253                  104           136
# ...

# %%
categorical = []
continuous = []

for col in df.columns:
    if df[col].dtype == 'object':
        categorical.append(col)
    else:
        continuous.append(col)
print(col)
# Out:
# unique_cust_id

# %%
categorical = []
continuous = []

unique_threshold = 100  #Define the threshold for the number of unique values

for col in df.columns:
    unique_values = df[col].nunique()
    if unique_values <= unique_threshold:
        categorical.append(col)
    else:
        continuous.append(col)

print("Categorical columns:", categorical)
print("Continuous columns:",continuous)
# Out:
# Categorical columns: ['DIVISION', 'COMPANY_CODE', 'CREDIT_CONTROL_AREA', 'ORDER_CURRENCY', 'CREDIT_STATUS']
# Continuous columns: ['CUSTOMER_ORDER_ID', 'SALES_ORG', 'DISTRIBUTION_CHANNEL', 'RELEASED_CREDIT_VALUE', 'PURCHASE_ORDER_TYPE', 'ORDER_CREATION_DATE', 'ORDER_CREATION_TIME', 'SOLD_TO_PARTY', 'ORDER_AMOUNT', 'REQUESTED_DELIVERY_DATE', 'CUSTOMER_NUMBER', 'amount_in_usd', 'unique_cust_id']

# %% [markdown]
# Log Transformations on continuous columns

# %%
for col in continuous:
    if np.issubdtype(df[col].dtype, np.number):
        df[col] = df[col].apply(lambda x: np.log(x))

# %% [markdown]
# Try to extract new features by grouping existing columns

# %%
grouped_df = df.groupby('SALES_ORG').agg({
    'ORDER_AMOUNT': ['mean'],
    'RELEASED_CREDIT_VALUE': ['sum'],
    'CUSTOMER_NUMBER': ['nunique'],
    'amount_in_usd': ['max']
}).reset_index()

# %%
grouped_df.columns = ['SALES_ORG', 'avg_order_amount', 'total_credit_value', 'unique_customers', 'max_amount_usd']
grouped_df
# Out:
#       SALES_ORG  avg_order_amount  total_credit_value  unique_customers  \
# 0      7.649693               NaN          336.782176               141
# 1      7.650169               NaN                 NaN               129
# 2      7.650645               NaN                 NaN               116
# 3      7.651120               NaN                 NaN               124
# 4      7.651596               NaN                 NaN               137
# ...         ...               ...                 ...               ...
# 2406   8.413165               NaN                 NaN               143
# 2407   8.413387               NaN          286.548104               122
# 2408   8.413609               NaN                 NaN               139
# 2409   8.413831               NaN          259.260909               146
# 2410   8.414052               NaN          271.664811               138
#
#       max_amount_usd
# 0            7.50256
# 1            7.50256
# 2            7.50256
# ...

# %% [markdown]
# Create a heatmap to find correlation between the columns

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(df.corr(), annot=True ,fmt='.2g',linewidths=0.5)
plt.show()
# Out:
# <ipython-input-62-ede99b743348>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True ,fmt='.2g',linewidths=0.5)

# %% [markdown]
# Try to identify important or relevant columns for feature extraction

# %%
corr_matrix = df.corr()
corr_matrix['amount_in_usd'].sort_values(ascending=False)
# Out:
# <ipython-input-63-7c17552f32cb>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()
# amount_in_usd            1.000000
# ORDER_AMOUNT             0.902622
# RELEASED_CREDIT_VALUE    0.082296
# DIVISION                 0.062999
# ORDER_CURRENCY           0.034436
# PURCHASE_ORDER_TYPE      0.009297
# SOLD_TO_PARTY            0.000966
# DISTRIBUTION_CHANNEL     0.000933
# CUSTOMER_ORDER_ID       -0.000212
# SALES_ORG               -0.000483
# CREDIT_CONTROL_AREA     -0.001267
# COMPANY_CODE            -0.006716
# CREDIT_STATUS           -0.011927
# CUSTOMER_NUMBER         -0.028819
# ORDER_CREATION_TIME     -0.045206
# unique_cust_id          -0.050383
# Name: amount_in_usd, dtype: float64

# %% [markdown]
# ## MILESTONE-4 : ML Models and Evaluations

# %% [markdown]
# Modify the dataset to pass into any type of machine learning models.

# %%
# to select least important feature
numeric_columns=df.select_dtypes(include=[np.number])
correlation_target=numeric_columns.corr()['amount_in_usd'].abs().sort_values(ascending=True)
n = 20
relevant_cols = correlation_target[1:n+1].index.tolist()
relevant_cols
# Out:
# ['SALES_ORG',
#  'DISTRIBUTION_CHANNEL',
#  'SOLD_TO_PARTY',
#  'CREDIT_CONTROL_AREA',
#  'COMPANY_CODE',
#  'PURCHASE_ORDER_TYPE',
#  'CREDIT_STATUS',
#  'CUSTOMER_NUMBER',
#  'ORDER_CURRENCY',
#  'ORDER_CREATION_TIME',
#  'unique_cust_id',
#  'DIVISION',
#  'RELEASED_CREDIT_VALUE',
#  'ORDER_AMOUNT',
#  'amount_in_usd']

# %%
#Using label encoding on the relevant columns as a feature extraction
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
df['COMPANY_CODE_encoded']=label_encoder.fit_transform(df['COMPANY_CODE'])
df
# Out:
#         CUSTOMER_ORDER_ID  SALES_ORG  DISTRIBUTION_CHANNEL  DIVISION  \
# 119897          20.703616   8.370779              3.091042         0
# 141602          20.576736   7.816417              5.323010         0
# 4920            20.702634   7.859027              5.081404         0
# 213416          20.679108   7.812783              4.836282         0
# 258676          20.642270   7.978311              4.406719         0
# ...                   ...        ...                   ...       ...
# 668362          20.709758   8.325306              4.219508         1
# 668361          20.440816   8.219326              4.736198         1
# 668360          20.473946   8.230577              2.397895         1
# 668359          20.661464   8.060856              2.995732         1
# 542708          20.598858   7.677400              4.290459         1
#
#         RELEASED_CREDIT_VALUE  PURCHASE_ORDER_TYPE  COMPANY_CODE  \
# 119897               9.204121             4.644391           136
# ...

# %%
#Using datetime manipulation on the relevant columns as a feature extraction
df['REQUESTED_DELIVERY_DATE']=pd.to_datetime(df['REQUESTED_DELIVERY_DATE'])
df['delivery_dayofweek']=df['REQUESTED_DELIVERY_DATE'].dt.dayofweek
df['delivery_month']=df['REQUESTED_DELIVERY_DATE'].dt.month
df['delivery_year']=df['REQUESTED_DELIVERY_DATE'].dt.year
df
# Out:
#         CUSTOMER_ORDER_ID  SALES_ORG  DISTRIBUTION_CHANNEL  DIVISION  \
# 119897          20.703616   8.370779              3.091042         0
# 141602          20.576736   7.816417              5.323010         0
# 4920            20.702634   7.859027              5.081404         0
# 213416          20.679108   7.812783              4.836282         0
# 258676          20.642270   7.978311              4.406719         0
# ...                   ...        ...                   ...       ...
# 668362          20.709758   8.325306              4.219508         1
# 668361          20.440816   8.219326              4.736198         1
# 668360          20.473946   8.230577              2.397895         1
# 668359          20.661464   8.060856              2.995732         1
# 542708          20.598858   7.677400              4.290459         1
#
#         RELEASED_CREDIT_VALUE  PURCHASE_ORDER_TYPE  COMPANY_CODE  \
# 119897               9.204121             4.644391           136
# ...

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace=True)

# %%
Y = df['amount_in_usd']
X = df.drop(['amount_in_usd', 'PURCHASE_ORDER_TYPE', 'SOLD_TO_PARTY','ORDER_AMOUNT','DISTRIBUTION_CHANNEL',
 'SALES_ORG' ,'CREDIT_CONTROL_AREA', 'COMPANY_CODE', 'CUSTOMER_ORDER_ID','REQUESTED_DELIVERY_DATE','ORDER_CREATION_DATE'], axis=1)

# %%
X.columns
# Out:
# Index(['SALES_ORG', 'DISTRIBUTION_CHANNEL', 'DIVISION',
#        'RELEASED_CREDIT_VALUE', 'PURCHASE_ORDER_TYPE', 'ORDER_CREATION_TIME',
#        'CREDIT_CONTROL_AREA', 'SOLD_TO_PARTY', 'ORDER_CURRENCY',
#        'unique_cust_id', 'COMPANY_CODE_encoded', 'delivery_dayofweek',
#        'delivery_month', 'delivery_year'],
#       dtype='object')

# %%
from sklearn.model_selection import KFold

# %% [markdown]
# Try different machine learning models like -
# Linear Regression
# Support Vector Machine
# Decision Tree
# Random Forest
# AdaBoost
# Xgboost etc.

# %% [markdown]
# Perform Regression model evaluations like MSE, RMSE, R-Square etc.

# %%
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
pca = PCA(n_components=4)
X = pca.fit_transform(X)
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
#Linear Regression
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(X_train,Y_train)
Y_pred_train = linreg.predict(X_train)
Y_pred = linreg.predict(X_test)
Y_pred = pd.DataFrame(Y_pred)

print("MSE: ",mean_squared_error(Y_test,Y_pred)," \nR2: ",r2_score(Y_test,Y_pred)," \nRMSE: ",np.sqrt(mean_squared_error(Y_test,Y_pred)),"\nr2_train: ",r2_score(Y_train, Y_pred_train))
# Out:
# MSE:  1.7909399948633258
# R2:  0.017054683188529984
# RMSE:  1.3382600624928347
# r2_train:  0.017270694216248494

# %%
#Decision Tree
from sklearn.tree import DecisionTreeRegressor
dectree = DecisionTreeRegressor()
dectree.fit(X_train,Y_train)
Y_pred = dectree.predict(X_test)
Y_pred = pd.DataFrame(Y_pred)
print("MSE: ",mean_squared_error(Y_test,Y_pred)," \nR2: ",r2_score(Y_test,Y_pred)," \nRMSE: ",np.sqrt(mean_squared_error(Y_test,Y_pred)))
# Out:
# MSE:  1.0919583401626347
# R2:  0.40068604213733094
# RMSE:  1.044968104854227

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import pandas as pd

# Initialize the DecisionTreeRegressor
dectree = DecisionTreeRegressor()

# Set the number of folds for cross-validation
k = 5

# Create a k-fold cross-validation object
kfold = KFold(n_splits=k)

# Perform k-fold cross-validation
scores = cross_val_score(dectree, X_train, Y_train, cv=kfold)

# Fit the DecisionTreeRegressor to the training data
dectree.fit(X_train, Y_train)

# Predict on the test data
Y_pred = dectree.predict(X_test)

# Convert predictions to a DataFrame
Y_pred = pd.DataFrame(Y_pred)

# Calculate evaluation metrics
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)
rmse = np.sqrt(mse)

# Print the evaluation metrics
print("MSE:", mse)
print("R2:", r2)
print("RMSE:", rmse)

# Display cross-validation scores
print("Cross-Validation Scores:", scores)
print("Mean CV Score:", np.mean(scores))
print("Standard Deviation of CV Scores:", np.std(scores))
# Out:
# MSE: 1.0888768435273333
# R2: 0.40237730074740574
# RMSE: 1.0434926178595292
# Cross-Validation Scores: [0.37847218 0.38032409 0.37872699 0.39026339 0.38990759]
# Mean CV Score: 0.38353885044654806
# Standard Deviation of CV Scores: 0.005384052895835892

# %%
#Random Forest
# from sklearn.ensemble import RandomForestRegressor
# randfor = RandomForestRegressor()

# # Set the number of folds for cross-validation
# k = 5

# # Create a k-fold cross-validation object
# kfold = KFold(n_splits=k)

# # Perform k-fold cross-validation
# scores = cross_val_score(randfor, X_train,Y_train.ravel(), cv=kfold)

# randfor.fit(X_train,Y_train.ravel())
# # Predict on the test data
# Y_pred = randfor.predict(X_test)

# # Convert predictions to a DataFrame
# Y_pred = pd.DataFrame(Y_pred)

# # Calculate evaluation metrics
# mse = mean_squared_error(Y_test, Y_pred)
# r2 = r2_score(Y_test, Y_pred)
# rmse = np.sqrt(mse)

# # Print the evaluation metrics
# print("MSE:", mse)
# print("R2:", r2)
# print("RMSE:", rmse)

# # Display cross-validation scores
# print("Cross-Validation Scores:", scores)
# print("Mean CV Score:", np.mean(scores))
# print("Standard Deviation of CV Scores:", np.std(scores))

# %%
#AdaBoost
from sklearn.ensemble import AdaBoostRegressor
adaboost = AdaBoostRegressor()
adaboost.fit(X_train, Y_train.ravel())
Y_pred = adaboost.predict(X_test)
Y_pred = pd.DataFrame(Y_pred)
print("MSE: ",mean_squared_error(Y_test,Y_pred)," \nR2: ",r2_score(Y_test,Y_pred)," \nRMSE: ",np.sqrt(mean_squared_error(Y_test,Y_pred)))
# Out:
# MSE:  2.216543875374906
# R2:  -0.2165351313030337
# RMSE:  1.4888061913408697

# %%
#Xgboost
import xgboost as xgb
xgbreg = xgb.XGBRegressor()
xgbreg.fit(X_train, Y_train)
Y_pred = xgbreg.predict(X_test)
Y_pred = pd.DataFrame(Y_pred)
print("MSE: ",mean_squared_error(Y_test,Y_pred)," \nR2: ",r2_score(Y_test,Y_pred)," \nRMSE: ",np.sqrt(mean_squared_error(Y_test,Y_pred)))
# Out:
# MSE:  0.8616166325778267
# R2:  0.527107532185144
# RMSE:  0.9282330701810977

# %%
# # SVR
# from sklearn.svm import SVR
# svr = SVR()
# svr.fit(X_train, Y_train)
# Y_pred = svr.predict(X_test)
# Y_pred = pd.DataFrame(Y_pred)
# print("MSE: ",mean_squared_error(Y_test,Y_pred)," \nR2: ",r2_score(Y_test,Y_pred)," \nRMSE: ",np.sqrt(mean_squared_error(Y_test,Y_pred)))

# %% [markdown]
# Compare the accuracies of all the models.

# %% [markdown]
# Select the best possible model

# %%
models = pd.DataFrame({
    'Model': ['Linear Regression', 'Decision Tree', 'Random Forest', 'AdaBoost', 'XGBoost'],
    'MSE': [mean_squared_error(Y_test ,linreg.predict(X_test)), mean_squared_error(Y_test ,dectree.predict(X_test)), mean_squared_error(Y_test ,randfor.predict(X_test)), mean_squared_error(Y_test ,adaboost.predict(X_test)), mean_squared_error(Y_test ,xgbreg.predict(X_test))],
    'R2': [r2_score(Y_test ,linreg.predict(X_test)), r2_score(Y_test ,dectree.predict(X_test)), r2_score(Y_test ,randfor.predict(X_test)), r2_score(Y_test ,adaboost.predict(X_test)), r2_score(Y_test ,xgbreg.predict(X_test))],
    'RMSE': [np.sqrt(mean_squared_error(Y_test ,linreg.predict(X_test))), np.sqrt(mean_squared_error(Y_test ,dectree.predict(X_test))), np.sqrt(mean_squared_error(Y_test ,randfor.predict(X_test))), np.sqrt(mean_squared_error(Y_test ,adaboost.predict(X_test))), np.sqrt(mean_squared_error(Y_test ,xgbreg.predict(X_test)))]
})
models.sort_values(by='RMSE',ascending=True)
# Out:
#                Model       MSE        R2      RMSE
# 2      Random Forest  0.310482  0.829594  0.557209
# 4            XGBoost  0.861617  0.527108  0.928233
# 1      Decision Tree  1.088877  0.402377  1.043493
# 0  Linear Regression  1.790940  0.017055  1.338260
# 3           AdaBoost  2.216544 -0.216535  1.488806

# %% [markdown]
# ## RANDOM FOREST shows the best result.

# %% [markdown]
# Perform Hyperparameter tuning, select best hyperparameters by using appropriate algorithms

# %%
# from sklearn.model_selection import GridSearchCV

# # Hyperparameter tuning for RandomForest
# param_grid = {
#     'max_depth': [10, 20, 30],
#     'min_samples_leaf': [1, 3, 5],
#     'max_samples': [0.8, 1.0],
#     'n_estimators': [10, 20, 30]
# }

# rf=RandomForestRegressor()
# grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3,verbose=2,n_jobs=-1)

# grid_search.fit(X_train, Y_train)

# print("Grid Search Best Parameters: ", grid_search.best_params_)
# print("Grid Search Best Score: ", grid_search.best_score_)

# # Evaluate the best model on the test set
# best_rf = grid_search.best_estimator_
# accuracy = best_rf.score(X_test, Y_test)
# print("Test Set Accuracy: ", accuracy)

# %%
# from sklearn.model_selection import RandomizedSearchCV

# # Hyperparameter tuning for RandomForest
# param_grid = {
#     'max_depth': [10, 20, 30],
#     'min_samples_leaf': [1, 3, 5],
#     'max_samples': [0.8, 1.0],
#     'n_estimators': [10, 20, 30]
# }

# rf=RandomForestRegressor()
# rand_search = RandomizedSearchCV(estimator=rf, param_distributions=param_grid, cv=3,verbose=2,n_jobs=-1)

# rand_search.fit(X_train, Y_train)

# print("Randomized Search Best Parameters: ", rand_search.best_params_)
# print("Randomized Search Best Score: ", rand_search.best_score_)

# # Evaluate the best model on the test set
# best_rf = rand_search.best_estimator_
# accuracy = best_rf.score(X_test, Y_test)
# print("Test Set Accuracy: ", accuracy)

# %%
#Random Forest
from sklearn.ensemble import RandomForestRegressor
randfor = RandomForestRegressor(max_samples=0.75,random_state=42)
randfor.fit(X_test,Y_test.ravel())
Y_pred = randfor.predict(X_test)
Y_pred = pd.DataFrame(Y_pred)
print("MSE: ",mean_squared_error(Y_test,Y_pred)," \nR2: ",r2_score(Y_test,Y_pred)," \nRMSE: ",np.sqrt(mean_squared_error(Y_test,Y_pred)))
# Out:
# MSE:  0.31048192024717686
# R2:  0.8295940956498182
# RMSE:  0.5572090453745137

# %%
#Xgboost
import xgboost as xgb
params = {
    'booster': 'gbtree',
    'nthread': 10,
    'learning_rate': 0.1,
    'n_estimators': 200, #no. of trees in the forest
    'max_depth': 5,
    'min_child_weight': 2,
}
xgbreg = xgb.XGBRegressor(**params)
xgbreg.fit(X_train, Y_train)
Y_pred = xgbreg.predict(X_test)
Y_pred = pd.DataFrame(Y_pred)
print("MSE: ",mean_squared_error(Y_test,Y_pred)," \nR2: ",r2_score(Y_test,Y_pred)," \nRMSE: ",np.sqrt(mean_squared_error(Y_test,Y_pred)))
# Out:
# MSE:  0.9838041442391
# R2:  0.4600457418935818
# RMSE:  0.9918690156664337

# %% [markdown]
# ## RANDOM FOREST IS THE BEST POSSIBLE MODEL WITH THE ACCURACY OF 82.95%
